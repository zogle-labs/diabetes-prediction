# %%
import sys
import os
sys.path.append(os.path.abspath('..'))
from src.data_processing.data_loader import load_data, preprocess
from src.train import train_model, save_model
from src.evaluate import evaluate_model

df = load_data()
X, y = preprocess(df)

model, X_train, X_test, y_train, y_test = train_model(X, y)

evaluate_model(model, X_test, y_test)

save_model(model)
# Out:
# /Users/shashankr/Development/Artificial Intelligence Projects/Zogle Labs/Learning Projects/Diabetes-prediction/src/data_processing/data_loader.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Hour'] = df['Time'].dt.hour
# /Users/shashankr/Development/Artificial Intelligence Projects/Zogle Labs/Learning Projects/Diabetes-prediction/src/data_processing/data_loader.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Minute'] = df['Time'].dt.minute
# /Users/shashankr/Development/Artificial Intelligence Projects/Zogle Labs/Learning Projects/Diabetes-prediction/src/data_processing/data_loader.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Hour_sin'] = np.sin(2 * np.pi * df['Hour'] / 24)
# /Users/shashankr/Development/Artificial Intelligence Projects/Zogle Labs/Learning Projects/Diabetes-prediction/src/data_processing/data_loader.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Hour_cos'] = np.cos(2 * np.pi * df['Hour'] / 24)
# /Users/shashankr/Development/Artificial Intelligence Projects/Zogle Labs/Learning Projects/Diabetes-prediction/src/data_processing/data_loader.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Min_sin']  = np.sin(2 * np.pi * df['Minute'] / 60)
# /Users/shashankr/Development/Artificial Intelligence Projects/Zogle Labs/Learning Projects/Diabetes-prediction/src/data_processing/data_loader.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Min_cos']  = np.cos(2 * np.pi * df['Minute'] / 60)
# /Users/shashankr/Development/Artificial Intelligence Projects/Zogle Labs/Learning Projects/Diabetes-prediction/src/data_processing/data_loader.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Value'] = pd.to_numeric(df['Value'], errors='coerce')
# /Users/shashankr/Development/Artificial Intelligence Projects/Zogle Labs/Learning Projects/Diabetes-prediction/src/data_processing/data_loader.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(subset=["Value"], inplace=True)
# Mean Absolute Error (MAE): 30.7413
# R² Score: 0.6771
